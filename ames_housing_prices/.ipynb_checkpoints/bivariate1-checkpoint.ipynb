# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
sns.set_style("whitegrid")

# %%
ames = pd.read_csv("data/train.csv")
ames.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %% [markdown]
# ### Continuous Variables

# %%
list1 = ['LotFrontage','LotArea','YearBuilt','YearRemodAdd','MasVnrArea','BsmtFinSF1','BsmtFinSF2','BsmtUnfSF','TotalBsmtSF']

# %%
# Correlation of these variables with target 'SalePrice'
ames[list1+['SalePrice']].corr()['SalePrice']
# Out:
# LotFrontage     0.351799
# LotArea         0.263843
# YearBuilt       0.522897
# YearRemodAdd    0.507101
# MasVnrArea      0.477493
# BsmtFinSF1      0.386420
# BsmtFinSF2     -0.011378
# BsmtUnfSF       0.214479
# TotalBsmtSF     0.613581
# SalePrice       1.000000
# Name: SalePrice, dtype: float64

# %%
fig2 = plt.figure(figsize=(14,14))
for i in range(1,10):
    ax = fig2.add_subplot(3,3,i)
    ax.scatter(ames[list1[i-1]],ames['SalePrice'], s=5)
    ax.set_xlabel(ames[list1[i-1]].name)

# %%
ames['SalePrice'].name
# Out:
# 'SalePrice'

# %%
plt.scatter(np.log(ames['LotArea']), ames['SalePrice'], s=2)

# %%
plt.scatter(np.log(ames['LotFrontage']), ames['SalePrice'], s=2)

# %%
plt.scatter(np.sqrt(ames['BsmtUnfSF']), ames['SalePrice'], s=2)

# %% [markdown]
# 'BsmtFinSF2' doesn't seem to affect 'SalePrice'. Even after binning.

# %%
list2 = ['1stFlrSF','2ndFlrSF','LowQualFinSF','GrLivArea','TotRmsAbvGrd','GarageYrBlt','GarageArea','WoodDeckSF','OpenPorchSF']

# %%
# Correlation of these variables with target 'SalePrice'
ames[list2+['SalePrice']].corr()['SalePrice']
# Out:
# 1stFlrSF        0.605852
# 2ndFlrSF        0.319334
# LowQualFinSF   -0.025606
# GrLivArea       0.708624
# TotRmsAbvGrd    0.533723
# GarageYrBlt     0.486362
# GarageArea      0.623431
# WoodDeckSF      0.324413
# OpenPorchSF     0.315856
# SalePrice       1.000000
# Name: SalePrice, dtype: float64

# %%
fig3 = plt.figure(figsize=(14,14))
for i in range(1,10):
    ax = fig3.add_subplot(3,3,i)
    ax.scatter(ames[list2[i-1]],ames['SalePrice'], s=5)
    ax.set_xlabel(ames[list2[i-1]].name)

# %% [markdown]
# 'LowQualFinSF' seems irrelevant. Even after binning.

# %%
list3 = ['EnclosedPorch','3SsnPorch','ScreenPorch','PoolArea','MiscVal','MoSold','YrSold']

# %%
# Correlation of these variables with target 'SalePrice'
ames[list3+['SalePrice']].corr()['SalePrice']
# Out:
# EnclosedPorch   -0.128578
# 3SsnPorch        0.044584
# ScreenPorch      0.111447
# PoolArea         0.092404
# MiscVal         -0.021190
# MoSold           0.046432
# YrSold          -0.028923
# SalePrice        1.000000
# Name: SalePrice, dtype: float64

# %%
fig4 = plt.figure(figsize=(14,14))
for i in range(1,len(list3)+1):
    ax = fig4.add_subplot(3,3,i)
    ax.scatter(ames[list3[i-1]],ames['SalePrice'], s=5)
    ax.set_xlabel(ames[list3[i-1]].name)

# %% [markdown]
# 3SsnPorch, ScreenPorch, PoolArea, MiscVal seems irrelevant, even after binning. MoSold and YrSold will be examined again as nominal variables.
